# %% [markdown]
#                                                  COVID - 19
#                                             ELKIN RAMIREZ GONZALEZ

# %%
import scipy.misc
import statistics
import numpy as np # algebra lineal y componente matematica (matrices, arrreglos)
import scipy # matematica
import pandas as pd #manejo de datos
from matplotlib import pyplot as plt #graficas
# %matplotlib inline
import seaborn as sb
import random
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from mpl_toolkits.mplot3d import Axes3D
import cv2

# %% [markdown]
# **ENTRADA DE LOS DATOS**

# %%
data = pd.read_csv('C:/Users/elkin/Documentos/data/Casos.csv', sep=';')
data.head(14217)
# Out:
#           Id    Fecha_de_notificación  Codigo_DIVIPOLA  Ciudad_de_ubicación  \
# 0          1  2020-03-02T00:00:00.000            11001          Bogotá D.C.
# 1          2  2020-03-06T00:00:00.000            76111  Guadalajara de Buga
# 2          3  2020-03-07T00:00:00.000             5001             Medellín
# 3          4  2020-03-09T00:00:00.000             5001             Medellín
# 4          5  2020-03-09T00:00:00.000             5001             Medellín
# ...      ...                      ...              ...                  ...
# 14211  14252  2020-05-12T00:00:00.000            13001  Cartagena de Indias
# 14212  14253  2020-05-12T00:00:00.000            13001  Cartagena de Indias
# 14213  14254  2020-05-12T00:00:00.000            13001  Cartagena de Indias
# 14214  14255  2020-05-09T00:00:00.000             5001             Medellín
# 14215  14256  2020-05-12T00:00:00.000             5001             Medellín
#
# ...

# %% [markdown]
# **IDENTIFICACION DE VARIABLES**

# %%
data.dtypes
# Out:
# Id                           int64
# Fecha_de_notificación       object
# Codigo_DIVIPOLA              int64
# Ciudad_de_ubicación         object
# Departamento o Distrito     object
# atención                    object
# Edad                         int64
# Sexo                        object
# Tipo                        object
# Estado                      object
# País_de_procedencia         object
# FIS                         object
# Fecha_de_muerte             object
# Fecha_diagnostico           object
# Fecha_recuperado            object
# fecha reporte web           object
# dtype: object

# %% [markdown]
# **ANALISIS ESTADISTICO**

# %%
data.describe()
# Out:
#                  Id  Codigo_DIVIPOLA          Edad
# count  14216.000000     14216.000000  14216.000000
# mean    7136.179727     32188.872397     39.786016
# std     4118.718202     29136.690714     18.759310
# min        1.000000        25.000000      0.000000
# 25%     3554.750000     11001.000000     26.000000
# 50%     7148.500000     13001.000000     37.000000
# 75%    10702.250000     52356.000000     52.000000
# max    14256.000000     97001.000000    103.000000

# %% [markdown]
# **CORRELACION**

# %%
data.corr()
# Out:
#                        Id  Codigo_DIVIPOLA      Edad
# Id               1.000000         0.043859 -0.074001
# Codigo_DIVIPOLA  0.043859         1.000000 -0.000766
# Edad            -0.074001        -0.000766  1.000000

# %% [markdown]
# **COVARIANZA**

# %%
data.cov()
# Out:
#                            Id  Codigo_DIVIPOLA         Edad
# Id               1.696384e+07     5.263323e+06 -5717.619646
# Codigo_DIVIPOLA  5.263323e+06     8.489467e+08  -418.870712
# Edad            -5.717620e+03    -4.188707e+02   351.911717

# %% [markdown]
# **PEARSON**

# %%
data.corr('pearson')
# Out:
#                        Id  Codigo_DIVIPOLA      Edad
# Id               1.000000         0.043859 -0.074001
# Codigo_DIVIPOLA  0.043859         1.000000 -0.000766
# Edad            -0.074001        -0.000766  1.000000

# %%
#GRAFICO DE PUNTO DE CORRELACION * PEARSON
plt.scatter(Edad, Id)
plt.xlabel('ID_de_casoo')
plt.ylabel('Edad')
plt.title('Relacion entre ID y edad')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-be21cc5e6494> in <module>
#       1 #GRAFICO DE PUNTO DE CORRELACION * PEARSON
# ----> 2 plt.scatter(Edad, Id)
#       3 plt.xlabel('ID_de_casoo')
#       4 plt.ylabel('Edad')
#       5 plt.title('Relacion entre ID y edad')
#
# NameError: name 'Edad' is not defined

# %%
Id.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4552fcb81ab0> in <module>
# ----> 1 Id.value_counts()
#
# NameError: name 'Id' is not defined
