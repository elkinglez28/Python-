# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sb

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
dataframe = pd.read_excel(r"C:/Users/elkin/Documentos/U/2020 1/DATA SCIENCE/Datos.xlsx")

# %%
dataframe.head(202)
# Out:
#             pais      region  Grupo    Fertilidad     PIB   Vida_Esperanza  \
# 0    Afghanistan        Asia   other        5.968    499.0           49.49
# 1        Albania      Europe   other        1.525   3677.2           80.40
# 2        Algeria      Africa  africa        2.142   4473.0           75.00
# 3         Angola      Africa  africa        5.135   4321.9           53.17
# 4      Argentina  Latin Amer   other        2.172   9162.1           79.89
# ..           ...         ...     ...          ...      ...             ...
# 188    Venezuela  Latin Amer   other        2.391  13502.7           77.73
# 189     Viet Nam        Asia   other        1.750   1182.7           77.44
# 190        Yemen        Asia   other        4.938   1437.2           67.66
# 191       Zambia      Africa  africa        6.300   1237.8           50.04
# 192     Zimbabwe      Africa  africa        3.109    573.1           52.72
#
#      Porcenteje_Plo  Mortalidad_Infantil
# ...

# %%
print(dataframe.groupby('pais').size())
# Out:
# pais
# Afghanistan    1
# Albania        1
# Algeria        1
# Angola         1
# Argentina      1
#               ..
# Venezuela      1
# Viet Nam       1
# Yemen          1
# Zambia         1
# Zimbabwe       1
# Length: 193, dtype: int64

# %%
dataframe.drop(['pais'], axis=1).hist()
plt.show()

# %%
dataframe.describe()
# Out:
#         Fertilidad           PIB   Vida_Esperanza  Porcenteje_Plo  \
# count   193.000000     193.000000      193.000000      193.000000
# mean      2.780302   12291.148187       72.079510       57.103627
# std       1.353583   17412.375959       10.182288       23.103473
# min       1.134000     114.800000       48.110000       11.000000
# 25%       1.750000    1239.800000       65.100000       39.000000
# 50%       2.264000    4495.800000       75.570000       59.000000
# 75%       3.700000   14497.300000       79.070000       75.000000
# max       6.925000  105095.400000       87.120000      100.000000
#
#        Mortalidad_Infantil
# count           193.000000
# mean             30.739046
# std              29.243749
# min               1.916000
# 25%               7.243000
# 50%              19.637000
# 75%              45.892000
# max             124.535000

# %%
dataframe['filtro']=(dataframe['Paises']+dataframe['pais']+dataframe['PIB'])
dataframe.drop(['filtro','Pais','PIB'], axis=1).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Paises'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-c5988a9c4a8b> in <module>
# ...
