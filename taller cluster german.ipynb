# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/elkin/Documentos/U/2020 1/DATA SCIENCE/german.csv', sep=';')
data.head()
# Out:
#   Estado_cuenta_corriente  Duracion_mes Historial_credito Proposito  \
# 0                     A11             6               A34       A43
# 1                     A12            48               A32       A43
# 2                     A14            12               A34       A46
# 3                     A11            42               A32       A42
# 4                     A11            24               A33       A40
#
#    Monto_credito Cuenta_ahorro_bonos Empleo_actual  Tasa_pago_porcentaje  \
# 0           1169                 A65           A75                     4
# 1           5951                 A61           A73                     2
# 2           2096                 A61           A74                     2
# 3           7882                 A61           A74                     2
# 4           4870                 A61           A73                     3
#
#   Estado_civil_sexo Otros_deudores  ...  Propiedad Edad  Planes_cuotas  \
# ...

# %%
sns.pairplot(data, size=2.5)
plt.tight_layout()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
